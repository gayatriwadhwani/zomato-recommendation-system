# %% [markdown]
# <h1 align='center'> Zomato Recommendation System</h1>
#
# ## Context
# I was always fascinated by the food culture of Bengaluru. Restaurants from all over the world can be found here in Bengaluru. From United States to Japan, Russia to Antarctica, you get all type of cuisines here. Delivery, Dine-out, Pubs, Bars, Drinks,Buffet, Desserts you name it and Bengaluru has it. Bengaluru is best place for foodies. The number of restaurant are increasing day by day. Currently which stands at approximately 12,000 restaurants. With such an high number of restaurants. This industry hasn't been saturated yet. And new restaurants are opening every day. However it has become difficult for them to compete with already established restaurants. The key issues that continue to pose a challenge to them include high real estate costs, rising food costs, shortage of quality manpower, fragmented supply chain and over-licensing. This Zomato data aims at analysing demography of the location. Most importantly it will help new restaurants in deciding their theme, menus, cuisine, cost etc for a particular location. It also aims at finding similarity between neighborhoods of Bengaluru on the basis of food. The dataset also contains reviews for each of the restaurant which will help in finding overall rating for the place.
#
# In this notebook I will try analyzing the Buisness Problem of Zomato and create a practical recommendation system for users.
#
# ![Zomato](https://miro.medium.com/max/1400/1*cQ6bco2E8qHAUqrqKlKwCQ.jpeg)
#
# ### What is Recommendation System?
# The rapid growth of data collection has led to a new era of information. Data is being used to create more efficient systems and this is where Recommendation Systems come into play. Recommendation Systems are a type of information filtering systems as they improve the quality of search results and provides items that are more relevant to the search item or are realted to the search history of the user.
# They are active information filtering systems which personalize the information coming to a user based on his interests, relevance of the information etc. Recommender systems are used widely for recommending movies, articles, restaurants, places to visit, items to buy etc.
#
#
# There are basically three types of recommender systems:-
#
#  - Demographic Filtering- They offer generalized recommendations to every user, based on movie popularity and/or genre. The System recommends the same movies to users with similar demographic features.
#
#  - Content Based Filtering- They suggest similar items based on a particular item. This system uses item metadata, such as genre, director, description, actors, etc. for movies, to make these recommendations.
#
#  - Collaborative Filtering- This system matches persons with similar interests and provides recommendations based on this matching. Collaborative filters do not require item metadata like its content-based counterparts.
#
#
# Here I will be using Content Based Filtering
#
# Content-Based Filtering: This method uses only information about the description and attributes of the items users has previously consumed to model user's preferences. In other words, these algorithms try to recommend items that are similar to those that a user liked in the past (or is examining in the present). In particular, various candidate items are compared with items previously rated by the user and the best-matching items are recommended.
#
# This data set consists of restaurants of Bangalore,India collected from Zomato.
#
# My aim is to create a content based recommender system in which when I will write a restaurant name, Recommender system will look at the reviews of other restaurants, and System will recommend us other restaurants with similar reviews and sort them from the highest rated.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Breakdown of this notebook:
# 1. **Loading the dataset:** Load the data and import the libraries. <br>
# 2. **Data Cleaning:** <br>
#  - Deleting redundant columns.
#  - Renaming the columns.
#  - Dropping duplicates.
#  - Cleaning individual columns.
#  - Remove the NaN values from the dataset
#  - #Some Transformations
# 3. **Text Preprocessing**
#  - Cleaning unnecessary words in the reviews
#  - Removing links and other unncessary items
#  - Removing Symbols
# 4. **Recommendation System**

# %% [markdown]
# ### Importing Libraries

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Loading the dataset

# %%
#reading the dataset
zomato_real=pd.read_csv("/content/drive/MyDrive/Banglore.csv")
zomato_real.head() # prints the first N rows of a DataFrame
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
zomato_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Data Cleaning and Feature Engineering

# %%
#Deleting Unnnecessary Columns
zomato=zomato_real.drop(['url','phone'],axis=1) #Dropping the column "phone", "url" and saving the new dataset as "zomato"

# %%
#After removing the extra columns
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         43942 non-null  object
#  5   votes                        51717 non-null  int64
#  6   location                     51696 non-null  object
#  7   rest_type                    51490 non-null  object
#  8   dish_liked                   23639 non-null  object
#  9   cuisines                     51672 non-null  object
#  10  approx_cost(for two people)  51371 non-null  object
#  11  reviews_list                 51717 non-null  object
#  12  menu_item                    51717 non-null  object
#  13  listed_in(type)              51717 non-null  object
#  14  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 5.9+ MB

# %%
#Removing the Duplicates
zomato.duplicated().sum()
zomato.drop_duplicates(inplace=True)

# %%
#Remove the NaN values from the dataset
zomato.isnull().sum()
zomato.dropna(how='any',inplace=True)
zomato.info() #.info() function is used to get a concise summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23395 entries, 0 to 51715
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      23395 non-null  object
#  1   name                         23395 non-null  object
#  2   online_order                 23395 non-null  object
#  3   book_table                   23395 non-null  object
#  4   rate                         23395 non-null  object
#  5   votes                        23395 non-null  int64
#  6   location                     23395 non-null  object
#  7   rest_type                    23395 non-null  object
#  8   dish_liked                   23395 non-null  object
#  9   cuisines                     23395 non-null  object
#  10  approx_cost(for two people)  23395 non-null  object
#  11  reviews_list                 23395 non-null  object
#  12  menu_item                    23395 non-null  object
#  13  listed_in(type)              23395 non-null  object
#  14  listed_in(city)              23395 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 2.9+ MB

# %%
#Reading Column Names
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
#Changing the column names
zomato = zomato.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                                  'listed_in(city)':'city'})
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'dish_liked', 'cuisines', 'cost',
#        'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %%
#Some Transformations
zomato['cost'] = zomato['cost'].astype(str) #Changing the cost to string
zomato['cost'] = zomato['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost
zomato['cost'] = zomato['cost'].astype(float) # Changing the cost to Float
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23395 entries, 0 to 51715
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       23395 non-null  object
#  1   name          23395 non-null  object
#  2   online_order  23395 non-null  object
#  3   book_table    23395 non-null  object
#  4   rate          23395 non-null  object
#  5   votes         23395 non-null  int64
#  6   location      23395 non-null  object
#  7   rest_type     23395 non-null  object
#  8   dish_liked    23395 non-null  object
#  9   cuisines      23395 non-null  object
#  10  cost          23395 non-null  float64
#  11  reviews_list  23395 non-null  object
#  12  menu_item     23395 non-null  object
#  13  type          23395 non-null  object
#  14  city          23395 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 2.9+ MB

# %%
#Reading Rate of dataset
zomato['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', 'NEW', '2.4/5', '2.2/5', '2.3/5',
#        '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5',
#        '2.7 /5', '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5',
#        '3.3 /5', '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5',
#        '3.5 /5', '3.1 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
#We remove the restaurent datas which has rate='NEW'
#Removing '/5' from Rates
zomato = zomato.loc[zomato.rate !='NEW']
zomato = zomato.loc[zomato.rate !='-'].reset_index(drop=True)
remove_slash = lambda x: x.replace('/5', '') if type(x) == np.str else x
zomato.rate = zomato.rate.apply(remove_slash).str.strip().astype('float')
zomato['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %% [markdown]
# Now we see that 'rate' column has converted to float datatype
#
#
# Now we will Label Encode the input variable columns into 0,1,2...

# %%
def Encode(zomato):
    for column in zomato.columns[~zomato.columns.isin(['rate', 'cost', 'votes'])]:
        zomato[column] = zomato[column].factorize()[0]
    return zomato

zomato_en = Encode(zomato.copy())

# %%
zomato_en['rate'] = zomato_en['rate'].fillna(zomato_en['rate'].mean())
zomato_en['cost'] = zomato_en['cost'].fillna(zomato_en['cost'].mean())

# %%
zomato_en.isna().sum()
# Out:
# address         0
# name            0
# online_order    0
# book_table      0
# rate            0
# votes           0
# location        0
# rest_type       0
# dish_liked      0
# cuisines        0
# cost            0
# reviews_list    0
# menu_item       0
# type            0
# city            0
# dtype: int64

# %%
zomato_en.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'dish_liked', 'cuisines', 'cost',
#        'reviews_list', 'menu_item', 'type', 'city'],
#       dtype='object')

# %% [markdown]
# **The highest correlation is between name and address which is 0.63 which is not of very much concern**

# %% [markdown]
# **Splitting dataset into train & test**

# %%
x = zomato_en.iloc[:,[2,3,5,6,7,8,9,11]]
y = zomato_en['rate']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=353)
x_train.head(10)
# Out:
#        online_order  book_table  votes  location  rest_type  dish_liked  \
# 3198              0           1    518        49          0        1721
# 21046             0           0     57        78          0        3298
# 12414             1           1    105        54         10        2482
# 5541              0           0   2229        27         52        1191
# 1891              1           1     59        17          0         979
# 15370             0           1    115        11          2        2001
# 10863             0           1    140        66          4        3481
# 15919             0           1     54        23          2        2018
# 4539              0           1    221        11         21         391
# 7256              0           1    205        20         24        2830
#
#        cuisines  reviews_list
# 3198          5          2380
# 21046      1487         10756
# 12414       161          3588
# 5541        616          3978
# 1891        507          1339
# 15370       862          9360
# 10863      1356          6579
# 15919       101          2808
# 4539        251           452
# 7256       1188          4677

# %%
y_train.head()
# Out:
# 3198     4.9
# 21046    3.7
# 12414    3.9
# 5541     4.4
# 1891     3.2
# Name: rate, dtype: float64

# %%
# Adjust the column names
zomato.name = zomato.name.apply(lambda x:x.title())
zomato.online_order.replace(('Yes','No'),(True, False),inplace=True)
zomato.book_table.replace(('Yes','No'),(True, False),inplace=True)
zomato.cost.unique()
# Out:
# array([800.  , 300.  , 600.  , 700.  , 550.  , 500.  , 450.  , 650.  ,
#        400.  , 750.  , 200.  , 850.  ,   1.2 , 150.  , 350.  , 250.  ,
#          1.5 ,   1.3 ,   1.  , 100.  , 900.  ,   1.1 ,   1.6 , 950.  ,
#        230.  ,   1.7 ,   1.35,   2.2 ,   1.4 ,   2.  ,   1.8 ,   1.9 ,
#        180.  , 330.  ,   2.5 ,   2.1 ,   3.  ,   2.8 ,   3.4 ,  40.  ,
#          1.25,   3.5 ,   4.  ,   2.4 ,   1.45,   3.2 ,   6.  ,   1.05,
#          4.1 ,   2.3 , 120.  ,   2.6 ,   5.  ,   3.7 ,   1.65,   2.7 ,
#          4.5 ])

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1    775  Banashankari        Casual Dining
# 1          True       False   4.1    787  Banashankari        Casual Dining
# 2          True       False   3.8    918  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7     88  Banashankari          Quick Bites
# 4         False       False   3.8    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
zomato['city'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %% [markdown]
# **As you see 'Location' columns has more sublocations
# and 'city' columns have a better Locations so we drop 'Location' column**

# %%
del zomato['location']
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes            rest_type  \
# 0          True        True   4.1    775        Casual Dining
# 1          True       False   4.1    787        Casual Dining
# 2          True       False   3.8    918  Cafe, Casual Dining
# 3         False       False   3.7     88          Quick Bites
# 4         False       False   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes            rest_type  \
# 0          True        True   4.1    775        Casual Dining
# 1          True       False   4.1    787        Casual Dining
# 2          True       False   3.8    918  Cafe, Casual Dining
# 3         False       False   3.7     88          Quick Bites
# 4         False       False   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
## Checking Null values
zomato.isnull().sum()
# Out:
# address         0
# name            0
# online_order    0
# book_table      0
# rate            0
# votes           0
# rest_type       0
# dish_liked      0
# cuisines        0
# cost            0
# reviews_list    0
# menu_item       0
# type            0
# city            0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# *Checking for correlation among all the x(inputs)*

# %%
corr = zomato_en.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)

# %% [markdown]
# i) No. of restaurants in a particular location

# %%
fig = plt.figure(figsize=(20,7))
loc = sns.countplot(x="location",data=zomato_real, palette = "Set1")
loc.set_xticklabels(loc.get_xticklabels(), rotation=90, ha="right")
plt.ylabel("Frequency",size=15)
plt.xlabel("Location",size=18)
loc
plt.title('NO. of restaurants in a Location',size = 20,pad=20)
# Out:
# Text(0.5, 1.0, 'NO. of restaurants in a Location')

# %% [markdown]
# ii) Frequency of different types of restaurants

# %%
fig = plt.figure(figsize=(17,5))
rest = sns.countplot(x="rest_type",data=zomato_real, palette = "Set1")
rest.set_xticklabels(rest.get_xticklabels(), rotation=90, ha="right")
plt.ylabel("Frequency",size=15)
plt.xlabel("Restaurant type",size=15)
rest 
plt.title('Restaurant types',fontsize = 20 ,pad=20)
# Out:
# Text(0.5, 1.0, 'Restaurant types')

# %% [markdown]
# iii) Most famous restaurant chains in Bengaluru

# %%
plt.figure(figsize=(15,7))
chains=zomato_real['name'].value_counts()[:20]
sns.barplot(x=chains,y=chains.index,palette='Set1')
plt.title("Most famous restaurant chains in Bangaluru",size=20,pad=20)
plt.xlabel("Number of outlets",size=15)
# Out:
# Text(0.5, 0, 'Number of outlets')

# %% [markdown]
# Number of restaurtants that take online_order

# %%
plt.figure(figsize=(10,10))

sns.countplot(zomato['online_order'])
plt.title("number of restaurtants that take online_order",fontsize=25,color='blue')
plt.ylabel("Count",fontsize=20)
plt.xlabel("Online order",fontsize=20)
plt.show()

# %% [markdown]
# Number of restaurants that have the option to book table

# %%
plt.figure(figsize=(10,10))

sns.countplot(zomato['book_table'])
plt.title("Number of restaurants that have the option to book table",fontsize=25,color='purple')
plt.ylabel("Count",fontsize=20)
plt.xlabel("Book Table",fontsize=20)
plt.show()

# %%
## Computing Mean Rating
restaurants = list(zomato['name'].unique())
zomato['Mean Rating'] = 0

for i in range(len(restaurants)):
    zomato['Mean Rating'][zomato['name'] == restaurants[i]] = zomato['rate'][zomato['name'] == restaurants[i]].mean()

# %%
plt.figure(figsize=(16,16))

ax=zomato.city.value_counts()
ax.plot(kind='pie',fontsize=20)

plt.title('number of restaurants in each area of banglore',fontsize=30,color='darkblue')
plt.show()

# %% [markdown]
# Percentage of number of restaurants in each area of banglore

# %%
plt.figure(figsize=(16,16))

ax=zomato.city.value_counts()[:10]
labels=zomato['city'].value_counts()[:10].index
plt.pie(ax,labels=labels,autopct='%.2f')
plt.title('number of restaurants in each area of banglore',fontsize=40,color='darkblue')
plt.show()

# %%
#TOP 10 location restaurants
plt.figure(figsize=(10,10))
ax=zomato.city.value_counts()[:10]
ax.plot(kind='bar')

# %%
#4.5 Type of Restaurant in City
plt.figure(figsize=(10,10))

ax=zomato.rest_type.value_counts()[:10]
label=zomato['rest_type'].value_counts()[:10].index
ax.plot(kind='pie',labels=label,autopct='%.2f')

plt.title("Type of Restaurant in City",fontsize=20,color='darkgreen')
plt.show()

# %%
#4.6 Number of Type of Restaurant in City
plt.figure(figsize=(10,10))

ax=zomato.rest_type.value_counts()[:10]
ax.plot(kind='bar')

plt.title("Number of Type of Restaurant in City",fontsize=25)
plt.xlabel("Type of Restaurants",fontsize=15)
plt.show()

# %%
zomato=zomato.rename(columns={"cost" : "avg_cost",
                      "listed_in(type)" : "meal_type", 
                      "listed_in(city)" : "city"})

# %%
zomato.dropna(subset=['rate','avg_cost','type'],inplace=True)

# %%
zomato['avg_cost']=zomato['avg_cost'].astype(int)
zomato.shape
# Out:
# (23248, 15)

# %% [markdown]
# Distribution of restaurants according to approx cost for two people

# %%
fig, ax = plt.subplots(figsize=[15,7])
sns.distplot(zomato_en['cost'],color="magenta")
ax.set_title('Approx cost for two people distribution',size=20,pad=15)
plt.xlabel('Approx cost for two people',size = 15)
plt.ylabel('Percentage of restaurants',size = 15)
# Out:
# Text(0, 0.5, 'Percentage of restaurants')

# %%
# Percentage of Average cost for two person
plt.figure(figsize=(10,10))

ax=zomato.avg_cost.value_counts()[:10]
label=zomato['avg_cost'].value_counts()[:10].index

plt.pie(ax,labels=label,autopct='%.2f')

plt.title("'Average cost for two person",fontsize=25)
plt.show()

# %%
#4.8 Top 10 dished_liked in Bangalore
plt.figure(figsize=(10,10))
ax=zomato['dish_liked'].value_counts()[:10]
ax.plot(kind='bar')
plt.title("Top 10 dished_liked in Bangalore",fontsize=25,color='purple')
plt.show()

# %%
#Top 10 dished_liked in Bangalore
plt.figure(figsize=(10,10))
ax=zomato.dish_liked.value_counts()[:10]
label=zomato['dish_liked'].value_counts()[:10].index

plt.pie(ax,labels=label,autopct='%.2f')

plt.title("Top 10 dishes liked in Bangalore",fontsize=15)
plt.show()

# %% [markdown]
# Most popular cuisines of Bangalore

# %%
plt.figure(figsize=(15,8))
cuisines=zomato['cuisines'].value_counts()[:15]
sns.barplot(cuisines,cuisines.index)
plt.title('Most popular cuisines of Bangalore', size = 20, pad = 15)
plt.xlabel('No. of restaurants',size = 15)
# Out:
# Text(0.5, 0, 'No. of restaurants')

# %%
#Rate VS Online Order
plt.figure(figsize=(16,16))

sns.countplot(x=zomato['rate'],hue=zomato['online_order'])
plt.title("Rate VS Online order",fontsize=25)
plt.ylabel("Restaurants that Accept/Not Accepting online orders",fontsize=20)
plt.xlabel("rate",fontsize=20)
plt.show()

# %% [markdown]
# Restaurant rating distribution

# %%
plt.figure(figsize=(15,8))
rating = zomato['rate']
plt.hist(rating,bins=20,color="blue")
plt.title('Restaurant rating distribution', size = 20, pad = 15)
plt.xlabel('Rating',size = 15)
plt.ylabel('No. of restaurants',size = 15)
# Out:
# Text(0, 0.5, 'No. of restaurants')

# %% [markdown]
# Approx cost for 2 people distribution with density plot

# %%
plt.figure(figsize=(15,8))
sns.violinplot(zomato.avg_cost)
plt.title('Approx cost for 2 people distribution', size = 20, pad = 15)
plt.xlabel('Approx cost for 2 people',size = 15)
plt.ylabel('Density',size = 15)
# Out:
# Text(0, 0.5, 'Density')

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes            rest_type  \
# 0          True        True   4.1    775        Casual Dining
# 1          True       False   4.1    787        Casual Dining
# 2          True       False   3.8    918  Cafe, Casual Dining
# 3         False       False   3.7     88          Quick Bites
# 4         False       False   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines  avg_cost  \
# 0  North Indian, Mughlai, Chinese       800
# 1     Chinese, North Indian, Thai       800
# 2          Cafe, Mexican, Italian       800
# 3      South Indian, North Indian       300
# 4        North Indian, Rajasthani       600
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city  Mean Rating
# 0  Banashankari     4.118182
# 1  Banashankari     4.100000
# 2  Banashankari     3.800000
# 3  Banashankari     3.700000
# 4  Banashankari     3.800000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (1,5))

zomato[['Mean Rating']] = scaler.fit_transform(zomato[['Mean Rating']]).round(2)

zomato.sample(3)
# Out:
#                                                  address                name  \
# 12805  1131, 17th Cross, 7th Sector, Near Vasan Eye C...  Reddy'S Restaurant
# 18045  5, 4th Floor, Above GIRIAS, 15th Cross, Malles...                1947
# 15973  5th Cross, 4th Main Road, Behind Ayyappa Templ...   Kapoor'S Biriyani
#
#        online_order  book_table  rate  votes      rest_type  \
# 12805          True       False   3.7    141  Casual Dining
# 18045         False        True   4.0   1070  Casual Dining
# 15973          True       False   3.3    334    Quick Bites
#
#                                               dish_liked  \
# 12805     Chicken Biryani, Mutton Roganjosh, Andhra Meal
# 18045  Jal-jeera, Roti, Dhokla, Biryani, Kheer, Chaac...
# 15973                          Raita, Hyderabadi Biryani
#
#                                      cuisines  avg_cost  \
# 12805  Andhra, Biryani, South Indian, Chinese       500
# 18045                   North Indian, Chinese       950
# 15973                   Biryani, North Indian       400
#
#                                             reviews_list menu_item      type  \
# 12805  [('Rated 3.0', "RATED\n  Don't have a picture ...        []  Dine-out
# 18045  [('Rated 4.0', 'RATED\n  Went here for a buffe...        []  Dine-out
# 15973  [('Rated 1.0', 'RATED\n  Total waste of money,...        []  Delivery
#
#                         city  Mean Rating
# 12805  Koramangala 4th Block         3.45
# 18045           Malleshwaram         3.87
# 15973  Koramangala 7th Block         2.94

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes            rest_type  \
# 0          True        True   4.1    775        Casual Dining
# 1          True       False   4.1    787        Casual Dining
# 2          True       False   3.8    918  Cafe, Casual Dining
# 3         False       False   3.7     88          Quick Bites
# 4         False       False   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines  avg_cost  \
# 0  North Indian, Mughlai, Chinese       800
# 1     Chinese, North Indian, Thai       800
# 2          Cafe, Mexican, Italian       800
# 3      South Indian, North Indian       300
# 4        North Indian, Rajasthani       600
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city  Mean Rating
# 0  Banashankari         3.99
# 1  Banashankari         3.97
# 2  Banashankari         3.58
# 3  Banashankari         3.45
# 4  Banashankari         3.58

# %%
## Text Preprocessing

# %% [markdown]
# Some of the common text preprocessing / cleaning steps are:
#
#  - Lower casing
#  - Removal of Punctuations
#  - Removal of Stopwords
#  - Removal of URLs
#  - Spelling correction

# %%
# 5 examples of these columns before text processing:
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 21428  [('Rated 3.0', 'RATED\n  They offer a variety ...
# 16566  [('Rated 4.0', 'RATED\n  Have had normal chick...
# 12118  [('Rated 5.0', 'RATED\n  This place might look...
# 9287   [('Rated 5.0', "RATED\n  From ages they have b...
# 21817  [('Rated 4.0', "RATED\n  A little on the exper...
#
#                                   cuisines
# 21428                       Tibetan, Momos
# 16566    Chinese, Momos, Nepalese, Tibetan
# 12118         North Indian, Chinese, Kebab
# 9287                   Ice Cream, Desserts
# 21817  Cafe, Continental, American, Burger

# %%
## Lower Casing
zomato["reviews_list"] = zomato["reviews_list"].str.lower()
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 11684  [('rated 4.0', 'rated\n  heaven for the people...
# 7877   [('rated 3.0', 'rated\n  been here for dinner ...
# 875    [('rated 5.0', 'rated\n  this is a small, cute...
# 124    [('rated 3.0', 'rated\n  food 3/5\nambience 3/...
# 13362  [('rated 4.0', 'rated\n  amazing ambience. goo...
#
#                                            cuisines
# 11684      North Indian, Cafe, Fast Food, Beverages
# 7877   North Indian, South Indian, Chinese, Seafood
# 875            North Indian, Fast Food, Street Food
# 124                                    North Indian
# 13362                     Cafe, Continental, Burger

# %%
## Removal of Puctuations
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_punctuation(text))
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 11474  rated 40 ratedn  ordered chicken fried ricenã...
# 11297  rated 30 ratedn  good place to satisfy the swe...
# 2570   rated 40 ratedn  huge place interiors are done...
# 7549   rated 40 ratedn  nice place located in sarjapu...
# 5162   rated 40 ratedn  surprised to see an entire ea...
#
#                                          cuisines
# 11474                                     Chinese
# 11297                         Mithai, Street Food
# 2570                      Continental, BBQ, Salad
# 7549                    North Indian, Street Food
# 5162   Beverages, Cafe, Desserts, Spanish, Bakery

# %%
## Removal of URLS
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_urls(text))

# %%
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 5877   rated 30 ratedn  located above starbucks on ch...
# 21750  rated 30 ratedn  biriyani was good but i have ...
# 16378  rated 50 ratedn  a cafe with a very unique con...
# 15496  rated 50 ratedn  we had the yummiessst raspber...
# 14576  rated 50 ratedn  i havenãx83ãx83ãx82ãx83ã...
#
#                                                 cuisines
# 5877       Finger Food, Continental, Asian, North Indian
# 21750                     Biryani, North Indian, Chinese
# 16378  Chinese, American, Continental, Italian, North...
# 15496                                               Cafe
# 14576                                           Desserts

# %%
# RESTAURANT NAMES:
restaurant_names = list(zomato['name'].unique())
restaurant_names
# Out:
# ['Jalsa',
#  'Spice Elephant',
#  'San Churro Cafe',
#  'Addhuri Udupi Bhojana',
#  'Grand Village',
#  'Timepass Dinner',
#  'Onesta',
#  'Penthouse Cafe',
#  'Smacznego',
#  'Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Down The Alley',
#  'Cafe Shuffle',
#  'The Coffee Shack',
#  'Caf-Eleven',
#  'Cafe Vivacity',
#  'Catch-Up-Ino',
#  "Kirthi'S Biryani",
#  'T3H Cafe',
#  'The Vintage Cafe',
#  'Woodee Pizza',
#  'My Tea House',
#  "Srinathji'S Cafe",
#  'Redberrys',
#  'Foodiction',
#  'Ovenstory Pizza',
#  'Faasos',
#  'Behrouz Biryani',
#  'Szechuan Dragon',
#  'Empire Restaurant',
#  'Chaatimes',
#  "Mcdonald'S",
#  "Domino'S Pizza",
#  'Hotboxit',
#  'Kitchen Garden',
#  'Recipe',
#  'Beijing Bites',
#  'Tasty Bytes',
#  'Corner House Ice Cream',
#  'Biryanis And More',
#  'Roving Feast',
#  'Freshmenu',
#  'Wamama',
#  'Peppy Peppers',
#  'Goa 0 Km',
#  '1947',
#  'Kabab Magic',
#  'Gustoes Beer House',
#  'The Biryani Cafe',
#  'Rolls On Wheels',
#  'Sri Guru Kottureshwara Davangere Benne Dosa',
#  'Upahar Sagar',
#  'Frozen Bottle',
#  'Meghana Foods',
#  'Nandhini Deluxe',
#  "Vi Ra'S Bar And Restaurant",
#  'Chatar Patar',
#  'Polar Bear',
#  "Kidambi'S Kitchen",
#  'Mane Thindi',
#  'Floured-Baked With Love',
#  'Bengaluru Coffee House',
#  'Anna Kuteera',
#  'Darbar',
#  'Sri Udupi Food Hub',
#  'House Of Kebabs',
#  'Roll N Rock',
#  'Box8- Desi Meals',
#  'Kfc',
#  'Roll Over',
#  'Imperial Restaurant',
#  'Wahab',
#  'Canton',
#  'The Blue Wagon - Kitchen',
#  'Patio 805',
#  'Lassi Corner',
#  'Sagar Deluxe',
#  'Energy Addaa',
#  'Tandoori Knight',
#  'Dev Sagar - Food Street',
#  'Mitraa Da Pizza',
#  'Grazers',
#  'Shakes Theory',
#  '@Italy',
#  'Old Mumbai Ice Cream',
#  'Donne Biriyani House',
#  "Kedia'S Fun Food",
#  'Just Shawarma',
#  'Mini Punjabi Dhaba',
#  'Gokul Veg',
#  'Olive - Era',
#  'Gama Gama',
#  'Pizza Hut',
#  'Mangalore Pearl',
#  'Twiststick House',
#  'Cool Corner',
#  'Pizza Mane',
#  'Dal Tadkaa',
#  'Chutney Chang',
#  'Mystique Palate',
#  'Thamboola',
#  'Castle Rock',
#  'Vietnamese Kitchen',
#  'Toscano',
#  'Stoned Monkey',
#  'Central Jail Restaurant',
#  'Bella',
#  'New Prashanth Hotel',
#  'Karma Kaapi',
#  "Tiwari'S",
#  'Pizza Stop',
#  "Biggies Burger 'N' More",
#  "Kollapuri'S",
#  'Rs Shiv Sagar',
#  'Harshi Super Sandwich',
#  'Ugadi',
#  'Subway',
#  'The Lassi Park',
#  'A2B - Adyar Ananda Bhavan',
#  'Srikrishna Bhavan',
#  'Green Gardenia',
#  'J Spice',
#  'Hatti Kaapi',
#  'Upahara Darshini',
#  'The Chaat Shop',
#  'Samskruti - Sanman Gardenia',
#  'Chumma Delicious',
#  'Dwaraka Grand',
#  'Gufha - The President Hotel',
#  'Mojo Pizza - 2X Toppings',
#  'South Kitchen',
#  'Chung Wah',
#  'Prems Graama Bhojanam',
#  'Java City',
#  'Kamat Bugle Rock',
#  'Puliyogare Point',
#  'Bangalore Agarwal Bhavan',
#  'Rustic Stove',
#  'De Thaali',
#  'Matru Sagar',
#  'Sea Spice By 7 Star',
#  'Desi Dawat',
#  'Cafe Aira',
#  'Mast Punjabi',
#  'South Grand',
#  'The Pizzeria',
#  'Ruchis Point',
#  'Firangi Bake',
#  'The Royal Corner - Pai Viceroy',
#  'Hara Fine Dine',
#  'Chocoberry',
#  'Waffle-A-Go Go',
#  'Cross Road Cafe',
#  'Bakers Town',
#  'Ivy',
#  'The Airos',
#  'Chai Kraft',
#  'The Trundle',
#  'The Krishna Grand Xpress',
#  'Udupi Grand',
#  'Little Cafe',
#  '1980S Games Cafe',
#  'Kadala Tarangaa',
#  'As On Fire',
#  'Curry Leaves',
#  'Magic Meals',
#  'Desi Cream Junction',
#  'Eat Repeat',
#  'Salut',
#  "Sandwich Mama'S And Frozen Monster",
#  'Food Springs',
#  "Chung'S Chinese Corner",
#  'Eurasia Pasta And Barbeque By Little Italy',
#  'Goli Vada Pav No. 1',
#  "Ragoo'S",
#  'Pure & Natural',
#  'Maiyas',
#  'Sip N Dine',
#  'Cafe Mondo',
#  'Jalpaan',
#  "Kataria'S Pakwan",
#  'Juicy Momos',
#  'Amande Patisserie',
#  'Anand Sweets And Savouries',
#  'Chicken Hunt',
#  'Swadesh Tadka',
#  'Cane-O-La',
#  'New Biryani Mane',
#  'Karnataka Bhel House',
#  'Sreeraj Lassi Bar',
#  "Bunt'S Biriyani Palace",
#  'Chai Point',
#  'Janahaar',
#  'Utsav',
#  'The Spice Saga',
#  'Subz',
#  'Mint And Mustard',
#  'Punjabi Raswada',
#  "Vinny'S",
#  "Kapoor'S Cafe",
#  'Sukh Sagar',
#  'Andhra Ruchulu',
#  'Steaming Mugs',
#  'Rajathadri Food Fort',
#  'Brew Meister',
#  'Rasoi',
#  'Mr. Singh Da Dhaba',
#  'Ayodhya Upachar',
#  'Biriyani Mane',
#  'Cafe Ajfan',
#  'Brundhavana Food Point',
#  'Slv Corner Restaurant',
#  'The Krishna Grand',
#  'Roti Ghar',
#  'Baisakhi',
#  'Poonam Sweets',
#  'Sri Venkateshwara Sweet Meat Stall',
#  'A2B Veg - Adyar Ananda Bhavan',
#  'Jcubez',
#  "Iyer'S Tiffin Centre",
#  'Taaza Thindi',
#  'Sri Laxmi Venkateshwara Coffee Bar',
#  'Messy Bowl',
#  'Hotel Mangala',
#  'Slv Swadishta',
#  'New Sagar Fast Food',
#  'Slv Refreshment',
#  'Kavali',
#  'Ranganna Military Hotel',
#  'Vidyarthi Bhavan',
#  'Bharjari Oota',
#  'Soho Bar & Grill',
#  'Bhavani Restaurant',
#  'Zephyr',
#  'Hotel Dwarka',
#  'Ma-Arya Family Restaurant',
#  'Udupi Sri Krishna Bhavan',
#  'Ice Thunder',
#  'Mahalaxmi Tiffin Room',
#  'Sandwichwallas',
#  'Basavanagudi Mylari',
#  'Pramukh Family Restaurant',
#  'Vybhava',
#  'Shree Venkateshwara North Karnataka Hotel',
#  'Belly Squad Food Truck',
#  'Deja Vu Resto Bar',
#  'Fattoush',
#  'Abhiruchi Hotel',
#  'Barbeque Nation',
#  'Sattvam',
#  '24Th Main',
#  'Zaitoon',
#  'Oye Amritsar',
#  'Melt - Eden Park',
#  'Spice Code',
#  'The Onyx - The Hhi Select Bengaluru',
#  'Sankranthi Veg Restaurant',
#  'Cafe Kabana',
#  'Butterly',
#  'Black Mug Cafe',
#  '#Refuel',
#  'Wafl',
#  'Vaho Kafe & Pressery',
#  'Dreamcatcher',
#  'Cafe Arabica',
#  'Kalmane Koffees',
#  'Brews N Bites',
#  'Slate Cafe',
#  'Dialogues',
#  'Mudpipe Cafe',
#  'Tab - Take A Break',
#  'Cafe Potpourri',
#  'Vinaya Coffee Moments',
#  'Cuppa',
#  'Skytouch Le Cafe',
#  'Eat.Fit',
#  'Sai Abhiruchi',
#  'Capsicum Family Restaurant',
#  'Easy Bites',
#  'Hiyar Majhe Kolkata',
#  'Sri Lakshmi Dhaba',
#  'Xo Belgian Waffle',
#  'Swadista Aahar',
#  'Al-Bek',
#  "Aniram'S",
#  'Punjabi Nawabi',
#  'Swad Punjab Da',
#  'Roti Wala',
#  'Midnight Mania',
#  'Kitchens@Jp Nagar',
#  'Krishna Kuteera',
#  'Apna Punjab',
#  'Paratha Junction',
#  'Nellore Bhojanam',
#  'Momoz',
#  'Kalingas',
#  'Kanteen The Eatery',
#  'Kullad Cafe',
#  'Litti Twist',
#  'Shanthi Sagar',
#  'Cakebuy',
#  'Five Star Chicken',
#  'Hind Ka Chulah',
#  'Bohra Bohra Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â©',
#  'Biryani Durbar',
#  'Mahesh Friends Food Center',
#  'Burger King',
#  "Dadi'S Dum Biryani",
#  'Alankrutha',
#  'Paradise',
#  'Adithya',
#  'Cheesiano Pizza',
#  "Dande'S Hyderabad Biryani",
#  'Upahara Bhavan',
#  'Shuddh Desi Khana',
#  'Aramane Donne Biriyani',
#  "Mani'S Dum Biryani",
#  'Amontron',
#  'Birinz',
#  'Hyderabadi Bawarchi',
#  'Fish Chain',
#  'Prasiddhi Food Corner',
#  'Hyderabad Biryaani House',
#  "Galito'S",
#  'Rajdhani Thali Restaurant',
#  'Phew (Play Hard Eat Wild)',
#  'Chicken County Grand',
#  'Savoury - Sea Shell Restaurant',
#  'Kundana',
#  'The Shawarma Shop',
#  'Punjabi Food Corner',
#  'Mealer.In',
#  'Pathaan Sir',
#  'Cold Stone Creamery',
#  'Amritsari Kulcha Land',
#  'Chokha Chowka',
#  'Gorbandh',
#  'Grills & Rolls',
#  'Bathinda Junction',
#  'Stories',
#  'Kanti Sweets',
#  'Seasons',
#  'Marwa Restaurant',
#  'Shanghai Court',
#  'Bhojohori Manna',
#  'Hunger Bee',
#  'Yum In My Tum',
#  'Biryani Miya',
#  'Chulha Chauki Da Dhaba',
#  "Magix'S Parattha Roll",
#  'Elegant Dining',
#  'Waffle Head',
#  'Basmati Delights',
#  'Samosa Singh',
#  'Cravings',
#  'Matka',
#  'Punjabi Swag',
#  'Taco Bell',
#  "Mother'S Rasoi",
#  'Dosa Bazaar',
#  'The Bong Palate',
#  'Bikaner Jn',
#  'Crunch Pizzas',
#  'Kakal-Kai Ruchi',
#  'Calorie Express',
#  'Bangalore Box',
#  'Chavadi',
#  'Nanna Munna Paratha House',
#  'Cucumber Town',
#  'Brewsky',
#  'Chefeana',
#  'Bangaliana',
#  'Gud Dhani',
#  'Deejas Kitchen',
#  'Pancuzzi',
#  "Zhang'S - Chinese Restaurant",
#  'Shagun Sweets & Foods',
#  "Dev'S Gugababa",
#  'Oogway Express',
#  'The Egg Factory',
#  'Chow San',
#  'Momo Jojo',
#  'Simply Indian',
#  "Rithika'S Kitchen",
#  'Punjabi Times',
#  'Cravy Wings',
#  'Funky Punjab',
#  'Punjabi Corner',
#  'Zeeshan',
#  'Ambara Gardenia',
#  'More Pizza',
#  'Crafted Plate',
#  "Shetty'S Kitchen",
#  'Machali Port',
#  'Garma Garam',
#  'The Coastal Crew By Fujian On 24Th',
#  'Bib - Breakfast In The Box',
#  'Tandoor And Spice',
#  'Rock Stone Ice Cream Factory',
#  'Paratha Plaza',
#  'Namma Kudla',
#  'Wangs Kitchen',
#  'Spice Up',
#  'Tempteys',
#  'Crumb Together',
#  'The Foodyz',
#  'Meat And Eat',
#  'Nagarjuna',
#  'Laddoos',
#  'Waffle Stories',
#  'Late Night',
#  'Waffle Walle',
#  'Dakshin Cafe',
#  'Shake It Off',
#  'Two Friends Cauldron',
#  'Bun Town',
#  'Pot Biryani',
#  'Mango Tree- The Beer Garden',
#  'The Jade Kitchen',
#  'Drunken Monkey',
#  'Intalia',
#  'Hotel Aradhana',
#  'The Chervil',
#  'New Royal Treat',
#  'I Cool',
#  'Asha Sweets Centre',
#  'Vinaya Cafe',
#  'World Of Waffles',
#  'Oottupura Family Restaurant',
#  'Vyanjan',
#  "Watson'S",
#  'Chicken Man',
#  'Nandhana Palace',
#  'On The Nose',
#  'Udupi Thaja Thindi',
#  'Baba Ka Dhaba',
#  'Natural Ice Cream',
#  "Churchill'S",
#  'The Chocolate Room',
#  'Aramane Restaurant',
#  'Bawarchi Inn',
#  "Ruh'S Cafe",
#  'California Burrito',
#  'Tandoor Garden',
#  'Caffe Pascucci',
#  'Chaitanya Cafe',
#  'Berrylicious',
#  'Pappu Da Dhaba',
#  'Smoke - The Sizzler House',
#  'Chung Wah Opus',
#  'Dream A Dozen',
#  'Bread Crumbs Bakery',
#  'Nite Out',
#  'Willys Top Cafe',
#  "Woody'S",
#  'The Curry Hut Plus',
#  'Zhangs Classic',
#  'Guru Greens',
#  'D View Cafe',
#  'Flavour Of China',
#  'Kabab Treat',
#  'Casa Piccosa',
#  'Bake Addiction',
#  'Tongue Twisters',
#  'Vaathsalya Millet Cafe',
#  'Guru Garden',
#  'Brewz Coffee',
#  'Athithi',
#  'Sri Bhagya Grand',
#  'Flavorsome Bakes',
#  'Mast Kalandar',
#  'Shiv Sagar',
#  'Coastal Inn',
#  'Bangalir Rannaghar',
#  "Lalchee'S Rasoi",
#  'Kailash Parbat',
#  'Tandoor Hut',
#  'Zaika Take Away',
#  'Malhar Maharashtrian Cuisine',
#  'Mandi',
#  'Pallavi North Indian Veg Restaurant',
#  'Idly Pidly',
#  "Vasudev Adiga'S",
#  'Tgi Fridays',
#  'Apsara Ice Cream',
#  "Targaryen'S Kitchen",
#  'Desi Vibes',
#  'Kulfi & More',
#  'Dal Roti',
#  'Status',
#  'Bottle Breacher',
#  'Kesariya',
#  'Swad Restaurant',
#  'Checkpost',
#  'Nandhini Paradise',
#  'New Kabab Plaza',
#  'Coastal Mama',
#  'Waah Biryani',
#  'Rara Avis',
#  'Baskin Robbins',
#  'Royal Chef Naati Oota',
#  'Flow - Terrace Bar & Grill',
#  'Sree Krishna Kafe',
#  'Dilish Kitchens',
#  'Daily Bread',
#  "Owl'S Kitchen",
#  'Deccan Spice',
#  'Desi Wok',
#  'Namana Garden',
#  'Andhra Grills',
#  'Petoo',
#  'Night Panda',
#  'Kamat Swaad',
#  'Ishta Cafe',
#  'Cafe Mist',
#  'Fat Chef Biryani Wale',
#  "Amma'S Pastries",
#  'World On A Swirl',
#  'Sweet Truth',
#  'Cream Stone',
#  "Calvin'S",
#  'Veruthe Oru Thattukada',
#  'Guru Paradise',
#  'Purani Dilli By Anand Sweets',
#  'Ingu Tengu',
#  'Green Onion',
#  'Panchami Garden',
#  'Hakuna Matata',
#  'Three Dots & A Dash',
#  'Hunger Camp',
#  '55 Wall Street',
#  'Parkview',
#  'Danapani',
#  'Inchara',
#  'Kabab Mehal',
#  'Chatori Gali',
#  'White Horse',
#  'Coconut Grove',
#  'Tree Top',
#  'The Sofraah Kebabs & Kurries - Eden Park Restaurants',
#  'The Yellow Chilli',
#  'Tea Villa Cafe',
#  'Cafe Cosy',
#  'Go Native',
#  'Alchemy Coffee Roasters',
#  'Rooftop Cafe',
#  'Enerjuvate Studio & Cafe',
#  'The Caramelts Cafe',
#  'Slimsins Cafe',
#  'Krazzy Folds',
#  'Starbucks',
#  'La Grande Cafe',
#  '4Th Tea Block',
#  'People Tree Cafe',
#  'Leon Grill',
#  'Dr. Bubbles',
#  'Shanmukha',
#  'Bhukkhad Baba',
#  'Mysuru Coffee Thindi',
#  'Smoke-A-Pot',
#  'The Biriyani Pedia',
#  'Sl Vadapav',
#  "Wazir'S",
#  'Krispy Kreme',
#  'Keventers',
#  'Tummy Fuel',
#  'Pani Kum Chai',
#  'Rajanna Military Hotel',
#  'Protein Grillhouse',
#  'Punjabi By Nature 2.0',
#  'Peace Restaurant',
#  'Pin Me Down',
#  'Swathi Deluxe Restaurant',
#  'Cakewala',
#  'The Belgian Waffle Co.',
#  'Wat-A-Burger!',
#  'Vakulaa Veg Restaurant',
#  'Malabar Bay',
#  'Khan Saheb Grills And Rolls',
#  'Desi Vdesi',
#  'Bhavani Chats N Juice',
#  'Lit Gastro Pub',
#  'Ice Cream Works',
#  'Rahhams',
#  'Bubblewrap Waffle Co.',
#  'Grillopia',
#  'Navami',
#  'Ibaco',
#  'City Durbar',
#  'Indori Chatorey',
#  'Mockaholic Restro Beer Cafe',
#  '3 Spice',
#  'Mug N Bean',
#  'Pop Hop',
#  '1441 Pizzeria',
#  'Hari Super Sandwich',
#  'Shyvan Restaurant',
#  'Mecaf Family Restaurant',
#  'By 2 Coffee',
#  'Euki',
#  'Kalpavriksha Upahara',
#  'New Punjabi Hotel',
#  'Ice Land',
#  'Rajvardhan Foods',
#  'Desi Rasoi',
#  'Red Onion',
#  'Baba Chatkora',
#  'Mainland China',
#  'Kamat Minerva',
#  'Davangere Benna Dose Hotel',
#  'Kudla - Hotel Ramanashree',
#  "Anupam'S Coastal Express",
#  "Polamma'S Mess",
#  'Cable Car',
#  'Vindu Andhra Ruchulu',
#  'Tawa Sagara',
#  'The Lounge - Eden Park Restaurants',
#  'Mayuri',
#  'Parika Multicuisine Restaurant',
#  'Eshanya',
#  'Siddique Kabab Centre',
#  'Clove Rooftop',
#  'Chef Master',
#  'Mane Holige',
#  'Nagarjuna Chimney',
#  "Mishra'S Pedha Big Foods",
#  'La Casa',
#  'Divina - Eden Park Restaurants',
#  'Parivar',
#  'V B Bakery',
#  'Milano Ice Cream',
#  'Cool Joint',
#  'The Rogue Elephant',
#  'Beetle Juice Bar - Springs Hotel & Spa',
#  'Mavalli Tiffin Room (Mtr)',
#  "Brahmin'S Coffee Bar",
#  'New Modern Hotel',
#  'Hotel Janatha',
#  'New Shanthi Sagar',
#  'Once Upon A Rooftop',
#  'Thyme & Whisk',
#  'Fusion Theory',
#  'Saarangi Fine Dining',
#  'Golden Oak - La Marvella Sarovar Premiere Hotel',
#  'Halli Jonne Biriyani',
#  'Bengaluru Cafe',
#  'Taj Restaurant',
#  'Brahmin Tiffins & Coffee',
#  "Sarvam'S",
#  "Iyengar'S Inn",
#  "Adiga'S",
#  'Pavithra Restaurant',
#  'Kava - Fairfield By Marriott',
#  "The Fisherman'S Wharf",
#  'Momo Cafe - Courtyard By Marriott',
#  'Ruh',
#  'Tipsy Bull - The Bar Exchange',
#  'Nook - Aloft Bengaluru Cessna Business Park',
#  'Chaarcoal',
#  'Sharaab Factory',
#  'Skylit - Citrus Hotels',
#  'Flavors Of India',
#  'Biso - Citrus Hotels',
#  "Chef'S Gallery",
#  "Palki'S",
#  'W Xyz Bar - Aloft Bengaluru Cessna Business Park',
#  'The Black Pearl',
#  'Jalsa Gold',
#  "Ab'S - Absolute Barbecues",
#  'The Hidden Home',
#  'Barbecoa',
#  'Opus Food Stories',
#  'Village - The Soul Of India',
#  'Little Italy',
#  'Xtreme Sports Bar',
#  'Rroyal Rajasthan',
#  'Flavours - Octave Hotel & Spa',
#  'Equinox Bar - Doubletree Suites By Hilton',
#  'The Salad Studio',
#  "Chef Baker'S",
#  'Cafe Coffee Day',
#  'Delitz Creamvilla Cafe',
#  'The Brewing Bean',
#  'Cafe Olive',
#  'Cafe Thulp',
#  'Stoner',
#  "Zoey'S",
#  'Eating Love',
#  'Light House Cafe',
#  'Sher-E-Punjab',
#  'Blue Berry Restaurant',
#  'Udupi Ruchi',
#  'Rangla Punjab',
#  'Thiruvithamkoor Restaurant',
#  'The Paratha Company',
#  'Nu.Tree',
#  'Best Of Bengal',
#  'New Punjabi Dhaba',
#  'Punjabi Dawat',
#  'Phulke Ghar Ke',
#  'The Meal Story',
#  'Meghana Foods Grand',
#  'Murli',
#  'Barbeque Delight',
#  'Basmati Restaurant',
#  'Fun Kitchen',
#  'Moriz Restaurant',
#  'Biryani Kitchen',
#  'Udupi Aatithya',
#  'Pepperwood',
#  'Al Daaz',
#  'Bihar Ki Shan',
#  'Sai Santhi Cafe',
#  'Shudh',
#  'Potful',
#  'Bahar Cafe',
#  'Dinepost9',
#  'Thalassery Restaurant',
#  'Sri Vishnu Grand',
#  'Bathinda Dine',
#  'Wow! Momo',
#  'Maa Bhook Lagi',
#  'Cake Town Cafe',
#  'Kairali Restaurant',
#  'Punjabi Food Point',
#  'Punjabi Tadka',
#  'Sri Udupi Park',
#  'The Punjabi Rasoi',
#  'Punjabi Nukkad Pure Veg',
#  'Kya Khaoge',
#  'Rayalaseema Chefs',
#  'The Nosh House',
#  'Savoury Restaurant',
#  'The Flying Cup',
#  'The Rasaganga',
#  'Sarjapur Social',
#  'Konaseema Kitchen',
#  "Psv'S Andhra Paradise",
#  'Maia - Eat | Bake | Mom',
#  'Happy Endings',
#  'Meghana Biryani',
#  'Andhra Bhojanam',
#  'Hyderabad Chefs',
#  'Byg Brewski Brewing Company',
#  'Suryawanshi',
#  "Chili'S American Grill & Bar",
#  'Delite Chaat House',
#  'Sri Krishna Sagar',
#  'Dhaba Estd 1986 Delhi',
#  'Inhouse Burger',
#  'Manchow',
#  'La Casa Brewery And Kitchen',
#  'Biriyani Zone',
#  "Soup'Ermanz Kitchen",
#  'Healthie',
#  'Sri Dalma',
#  "Baker'S Home",
#  'Al Khansah',
#  'Chullah Bhatti',
#  'Feel@Home',
#  'The Kebab House',
#  'Poha On Wheels',
#  'Float',
#  'Innerchef',
#  'Broadway - The Gourmet Theatre',
#  'Grigliato',
#  'Crunch Pizzas - Express Delivery',
#  'Parrattha Ssinghh',
#  'Yummy Tummy',
#  'Lungees Foods',
#  'Bombay Brasserie',
#  'Ajwa Thalassery Biryani',
#  'Folklore Restaurant',
#  'Napoli Italian Bistro',
#  'Uptown Sliders & Shakes',
#  'The Grub Central',
#  'Juice Junction Food Court',
#  'Sintales',
#  'The Litti Company',
#  'Vandana Andhra And Multi Cuisine',
#  'Aashish Foods',
#  'Rusbury Fresh Sweets And Savouries',
#  'Shree Khana Khazana',
#  'Moti Mahal Delux',
#  'Shri Vishnu Grand',
#  'Kitchen On Table',
#  'Charcoal Eats',
#  'Zayakedar',
#  'Amrutha Grand Restaurant',
#  "Nanda'S",
#  "Srinathji'S",
#  'Sichuan',
#  'Kanua',
#  "Dad'S Cookhouse",
#  'Abbabi Chicken',
#  'Azura Restaurant',
#  "Ritomi'S Lov",
#  'Southinn',
#  'Smoor',
#  'Mughal Treat',
#  'Le Charcoal Xpress',
#  'Foxtrot',
#  'Le Gateau - The Cake Shop',
#  'Deli Chats And Sweets',
#  'Eden Huts Restaurant',
#  'Baithak',
#  'Mumbai Xpress',
#  'Filmy Kitchen',
#  'Samaroh',
#  'Fusion Tadka',
#  'Nh-1',
#  'Matinee Bar & Kitchen',
#  'Delhi Restaurant',
#  'Chatorezz',
#  'Aapni Rasoi',
#  'Tapout Tavern',
#  'Shanghai Bistro',
#  'Hyderabad Biryaani Home',
#  "Pabrai'S Fresh & Naturelle Icecreams",
#  'Kritunga Restaurant',
#  'Kabab Mandra',
#  'Hoot',
#  'Ice N Fries Cafe',
#  'Nutty Squirrel',
#  'Cooking Mom',
#  'Biriyani Bungalow',
#  'Absolute Shawarma',
#  'The Irish House',
#  "Gusto'S Pizza",
#  'Mak N Vak - Fyn',
#  'Carlos Cake Cafe',
#  'Mighty Paws',
#  'Brimstone Cafe',
#  'Jashn',
#  'Health Zingo',
#  'Soul Treat',
#  'Kadala Teera',
#  'Red Stone Kitchen',
#  'Second Wife Cafe',
#  'The Vape',
#  'Nukkad',
#  'Burrito Boys',
#  'Dhaba Shaba',
#  'Ghar Ka Chulha',
#  'Cafe Daily Bread',
#  'Mishmash',
#  'Sri Sai Mango Tree Restaurant',
#  'Bhagini',
#  'Unico',
#  'Dosa Time',
#  "Ammi'S Biryani",
#  'Readybowl',
#  'Kawaii',
#  'B.M.W - Bhookh Mitaane Wala',
#  'Lovely Knights',
#  'Bonfooder',
#  'Cafe At The Atelier',
#  'Eatsomnia',
#  'Spice Of Kolkata',
#  'Spice Garden By Dum Mast Biryani',
#  'Parathabox',
#  'La-Pizza',
#  'That Garage Cafe',
#  'Cupcake Noggins',
#  'Swathi Deluxe',
#  'The Rig',
#  'Butter Side Up',
#  'Just Delhiwala',
#  'Foodzoo',
#  'Mumbai Kulfi',
#  'Wow Vada Pav',
#  'Nayi Dilli By Anand Sweets',
#  'Cauvery Hyderabadi Biriyani',
#  'Health Gourmet',
#  'Hokey Pokey Ice Creams',
#  'Warm Oven',
#  'Chullah Chandigarh',
#  'Dalchini',
#  "Bg'S Poolside Bar & Grill",
#  'Glassy',
#  'Opus Club',
#  'Vapour Brewpub And Diner',
#  'Blue Terrain - Novotel',
#  'Asia Alive - Doubletree Suites By Hilton',
#  'The Square - Novotel',
#  'Chez Nous - Novotel',
#  'Madurai Idly Shop',
#  'Ebony',
#  'Panchavati Gaurav Thali',
#  'Saatvikk',
#  '70 Brigade - Iris Hotel',
#  'Olive Bar And Kitchen',
#  'Jw Kitchen - Jw Marriott Bengaluru',
#  'The Tao Terraces',
#  'Rim Naam - The Oberoi',
#  'Oh! Calcutta',
#  'Caraway Kitchen - Conrad Bengaluru',
#  'Rasovara',
#  'Cubbon Pavilion - Itc Gardenia',
#  'Le Jardin - The Oberoi',
#  'Bbq@52',
#  'Konark Vegetarian Restaurant',
#  'The Spice Bazaar',
#  "Bbq'D - Global Grill & Brewery",
#  'The Market - The Ritz-Carlton',
#  'Welcomcafe Jacaranda - Welcomhotel Bengaluru',
#  'Season - Adarsh Hamilton',
#  'Puran Da Dhaba - The Pride Hotel',
#  'Cafe Mangii',
#  'Ithaca - The Chancery Pavilion',
#  'Tiger Trail - Ramada Hotel',
#  'Citrus Cafe - Lemon Tree Premier',
#  'The Oriental Spice - Ashraya Hotel',
#  'Pinxx - Royal Orchid Central',
#  'Monsoon - The Park Bangalore',
#  'Cafe Treat - The Pride Hotel',
#  'South Parade - The Chancery Hotel',
#  'Mint Masala',
#  "Curry With A 'K' - St. Mark'S Hotel",
#  'Northern Gate- Gateway Hotel',
#  'Canopy',
#  'Cafe @ Elanza',
#  'Sunehri',
#  'Spice It',
#  'Banjara Melting Pot',
#  'Zodiac - Fortune Select Jp Cosmos Hotel',
#  'One Atria Cafe',
#  'Blow',
#  'Cafe Azzure',
#  'Trick Or Treat',
#  "Fatso'S",
#  'Bon Sante',
#  'Brik Oven',
#  'Green Theory',
#  'Truffles',
#  'Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Felix',
#  'The White Room - Coffee & Kitchen',
#  'Matteo Coffea',
#  "Glen'S Bakehouse",
#  'Cafe Mozaic - Taj Mg Road Bengaluru',
#  "Smally'S Resto Cafe",
#  'Bengaluru Baking Company - Jw Marriott Bengaluru',
#  'Cafe Kaara',
#  'Japan Travel Cafe Azuki',
#  'Little Green Cafe',
#  "Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Mor'Ish",
#  'Skoolroom',
#  'Lakeview Milkbar',
#  "Wolf'Ish",
#  'Urban Solace - Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© For The Soul',
#  'Peppa Zzing',
#  'The Courtyard',
#  'Cafe Imroze',
#  'Kaara By The Lake',
#  'Happy Belly Bakes',
#  'Cafe Cassia& Deli',
#  'The Blackboard Bakery',
#  'Wafl Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â©',
#  'Fresh Pressery Cafe',
#  'Tata Cha',
#  'Moto Store & Cafã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â©',
#  'Driven Cafe',
#  'Soul Cafe',
#  'Cafe Aladdin',
#  'Cafe Cerrise',
#  'The Coffee Bean & Tea Leaf',
#  'Berrylicious Cafe',
#  'Hammered',
#  'Dolci Desserts',
#  'Infinitea Tea Room & Tea Store',
#  'Kerala Pavilion',
#  'Sri Ganesh Juice Junction',
#  "Dunkin' Donuts",
#  'Punjabi Dhaba',
#  'Tadkawala',
#  'Roti Shotti',
#  "Nando'S",
#  'Kc Das',
#  'M.M.A Kababs Rolls & Biryani Center',
#  'Richie Rich',
#  'Belgian Waffle Factory',
#  'No 10 Fort Cochin',
#  'Karama Restaurant',
#  "The Mughal'S",
#  'Kkr Foodies',
#  'Xpress Biryani',
#  'Soda Bottle Opener Wala',
#  'Smoke House Deli',
#  'Thai Chy',
#  'Kaati Zone',
#  'Portland Steakhouse & Cafe',
#  'Utse Kitchen',
#  'Alampur Bar And Restaurant',
#  'Sgs Non Veg - Gundu Pulav',
#  'Hotel Fanoos',
#  'Laughing Llama Gastropub',
#  'Oregano Pizzeria',
#  'The Good Grain',
#  'Pasta Street',
#  'Cita Pani',
#  'The Waffle Press',
#  'Delicacy',
#  ...]

# %%
def get_top_words(column, top_nu_of_words, nu_of_word):
    
    vec = CountVectorizer(ngram_range= nu_of_word, stop_words='english')
    
    bag_of_words = vec.fit_transform(column)
    
    sum_words = bag_of_words.sum(axis=0)
    
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    
    return words_freq[:top_nu_of_words]

# %%
zomato['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Andhra, Hyderabadi, Biryani',
#        'Andhra, North Indian, South Indian', 'Thai, Chinese, Momos'],
#       dtype=object)

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes            rest_type  \
# 0          True        True   4.1    775        Casual Dining
# 1          True       False   4.1    787        Casual Dining
# 2          True       False   3.8    918  Cafe, Casual Dining
# 3         False       False   3.7     88          Quick Bites
# 4         False       False   3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines  avg_cost  \
# 0  North Indian, Mughlai, Chinese       800
# 1     Chinese, North Indian, Thai       800
# 2          Cafe, Mexican, Italian       800
# 3      South Indian, North Indian       300
# 4        North Indian, Rajasthani       600
#
#                                         reviews_list menu_item    type  \
# 0  rated 40 ratedn  a beautiful place to dine int...        []  Buffet
# 1  rated 40 ratedn  had been here for dinner with...        []  Buffet
# 2  rated 30 ratedn  ambience is not that good eno...        []  Buffet
# 3  rated 40 ratedn  great food and proper karnata...        []  Buffet
# 4  rated 40 ratedn  very good restaurant in neigh...        []  Buffet
#
#            city  Mean Rating
# 0  Banashankari         3.99
# 1  Banashankari         3.97
# 2  Banashankari         3.58
# 3  Banashankari         3.45
# 4  Banashankari         3.58

# %%
zomato.sample(5)
# Out:
#                                                  address  \
# 418    324, 23rd Main, 3rd Cross, 2nd Stage, BTM, Ban...
# 17968   384/1, Bashyam Circle, Sadashiv Nagar, Bangalore
# 2147   Ground Floor, 14, HM Geneva House, Cunningham ...
# 22372  GMR Complex, Ground Floor, Opposite Bangalore ...
# 2229   No 6, Wood Street (Off Brigade Road), Ashok Na...
#
#                                        name  online_order  book_table  rate  \
# 418                          Swad Punjab Da          True       False   4.0
# 17968                           Mint Masala          True       False   3.8
# 2147                                    Kfc          True       False   3.6
# 22372                         Mast Kalandar         False       False   2.1
# 2229   Pabrai'S Fresh & Naturelle Icecreams          True       False   4.2
#
#        votes       rest_type  \
# 418      126     Quick Bites
# 17968    571   Casual Dining
# 2147     206     Quick Bites
# 22372    338   Casual Dining
# 2229     131  Dessert Parlor
#
#                                               dish_liked  \
# 418      Lassi, Roti, Veg Thali, Aloo Paratha, Egg Curry
# 17968  Salads, Salad, Veg Platter, Lunch Buffet, Kada...
# 2147   Burgers, Crispy Chicken, Chicken Zinger Burger...
# 22372  Khichda, Gaon Ki Thali, Buttermilk, Dal Makhan...
# 2229   Apple Pie, Mascarpone Cheese, Nolen Gurer Ice ...
#
#                     cuisines  avg_cost  \
# 418             North Indian       150
# 17968  Chinese, North Indian       800
# 2147       Burger, Fast Food       400
# 22372           North Indian       450
# 2229     Ice Cream, Desserts       180
#
#                                             reviews_list  \
# 418    rated 40 ratedn  if you can visit and eat then...
# 17968  rated 40 ratedn  been there for dinner with my...
# 2147   rated 50 ratedn  kfc is always kfc delicious c...
# 22372  rated 20 ratedn  food was kind of ok  nothing ...
# 2229   rated 50 ratedn  it was a pleasant surprise wh...
#
#                                                menu_item      type  \
# 418    ['Dal with Sabji Combo', 'Dal Sabji with 4 Cha...  Delivery
# 17968                                                 []  Delivery
# 2147   ['Boneless Strips', '4 Pc Hot Wings', 'Chicken...  Delivery
# 22372                                                 []  Delivery
# 2229   ['Anjeer Ice Cream [Per Scoop]', 'Apple Pie Ic...  Delivery
#
#                     city  Mean Rating
# 418    Bannerghatta Road         3.94
# 17968       Malleshwaram         2.66
# 2147        Brigade Road         3.39
# 22372      Sarjapur Road         1.72
# 2229        Brigade Road         4.01

# %%
zomato.shape
# Out:
# (23248, 15)

# %%
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'rest_type', 'dish_liked', 'cuisines', 'avg_cost', 'reviews_list',
#        'menu_item', 'type', 'city', 'Mean Rating'],
#       dtype='object')

# %%
zomato=zomato.drop(['address','rest_type', 'type', 'menu_item', 'votes'],axis=1)

# %%
import pandas

# Randomly sample 60% of your dataframe
df_percent = zomato.sample(frac=0.5)

# %%
df_percent.shape
# Out:
# (11624, 10)

# %% [markdown]
# ### Term Frequency-Inverse Document Frequency
# Term Frequency-Inverse Document Frequency (TF-IDF) vectors for each document. This will give you a matrix where each column represents a word in the overview vocabulary (all the words that appear in at least one document) and each column represents a restaurant, as before.
#
# TF-IDF is the statistical method of evaluating the significance of a word in a given document.
#
# TF — Term frequency(tf) refers to how many times a given term appears in a document.
#
# IDF — Inverse document frequency(idf) measures the weight of the word in the document, i.e if the word is common or rare in the entire document.
# The TF-IDF intuition follows that the terms that appear frequently in a document are less important than terms that rarely appear.
# Fortunately, scikit-learn gives you a built-in TfIdfVectorizer class that produces the TF-IDF matrix quite easily.

# %%
df_percent.set_index('name', inplace=True)

# %%
indices = pd.Series(df_percent.index)

# %%
# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend(name, cosine_similarities = cosine_similarities):
    
    # Create a list to put top 10 restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['cuisines', 'Mean Rating', 'avg_cost'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_percent[['cuisines','Mean Rating', 'avg_cost']][df_percent.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines','Mean Rating', 'avg_cost'], keep=False)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)
    
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new

# %%
# HERE IS A RANDOM RESTAURANT. LET'S SEE THE DETAILS ABOUT THIS RESTAURANT:
df_percent[df_percent.index == 'Kargeens'].head()
# Out:
#           online_order  book_table  rate  \
# name
# Kargeens          True       False   4.1
# Kargeens          True       False   4.1
# Kargeens          True       False   4.1
# Kargeens          True       False   3.9
# Kargeens          True       False   4.1
#
#                                                  dish_liked  \
# name
# Kargeens  Mocktails, Pasta Alfredo, Nachos, Veggie Pizza...
# Kargeens  Mocktails, Pasta Alfredo, Nachos, Veggie Pizza...
# Kargeens  Mocktails, Pasta Alfredo, Nachos, Veggie Pizza...
# Kargeens  Chocolate Milkshake, Mocktails, Burgers, Nacho...
# Kargeens  Mocktails, Pasta Alfredo, Nachos, Veggie Pizza...
#
#                                    cuisines  avg_cost  \
# name
# Kargeens         Cafe, Continental, Italian       600
# Kargeens         Cafe, Continental, Italian       600
# Kargeens         Cafe, Continental, Italian       600
# Kargeens  Cafe, Italian, Pizza, Continental       900
# Kargeens         Cafe, Continental, Italian       600
#
#                                                reviews_list  \
# name
# Kargeens  rated 40 ratedn  a very cool place for group o...
# Kargeens  rated 40 ratedn  a very cool place for group o...
# Kargeens  rated 40 ratedn  a very cool place for group o...
# Kargeens  rated 30 ratedn  at kargeens they serve variet...
# Kargeens  rated 40 ratedn  a very cool place for group o...
#
#                            city  Mean Rating
# name
# Kargeens  Koramangala 5th Block          3.9
# Kargeens  Koramangala 6th Block          3.9
# Kargeens  Koramangala 7th Block          3.9
# Kargeens           New BEL Road          3.9
# Kargeens  Koramangala 6th Block          3.9

# %%
recommend('Kargeens')
# Out:
# TOP 2 RESTAURANTS LIKE Kargeens WITH SIMILAR REVIEWS:
#                                        cuisines  Mean Rating avg_cost
# Cafe Aladdin                      Cafe, Chinese         3.71      500
# Bamboo Heights  Chinese, Fast Food, Continental         3.45      500

# %% [markdown]
# #### References
#  - [Recommender Systems in Python 101](https://www.kaggle.com/gspmoreira/recommender-systems-in-python-101)
#  - [How to build a Restaurant Recommendation Engine](https://medium.com/analytics-vidhya/how-to-build-a-restaurant-recommendation-engine-part-1-21aadb5dac6e)
#  - [Getting started with Text Preprocessing](kaggle.com/sudalairajkumar/getting-started-with-text-preprocessing)

# %% [markdown]
# ## End of the Notebook
